# %%
import os
import sqlite3
import psycopg2
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import boxcox
import matplotlib.pyplot as plt
from sqlalchemy.orm import sessionmaker
from sqlalchemy import create_engine, inspect, MetaData, Table

# %% [markdown]
# EXTRACT & LOAD RAW DATA TO DATABASE

# %%
def extract_data(folder_path):
    """
    Extract CSV data from the specified folder.
    
    arg:
    folder_path: Path to the folder containing CSV files.
    return: data_frames: list of pandas dataframes containing data from each of the csv files.
    
    """
    
    data_frames = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.csv'):
            file_path = os.path.join(folder_path, file_name)
            df = pd.read_csv(file_path)
            df['file_name'] = file_name # add a column to store the file name           
            data_frames.append(df)
            
    return data_frames

# %%
folder_path = r"C:\Users\admin\Desktop\Projects\Project FitBit\Fitabase Dataset"
data_frames = extract_data(folder_path)

# %%
USERNAME = 'fitbase'
PASSWORD = 'fitbase'
SERVER = 'localhost'
DATABASE = 'projectfitbase'

# %%
# Define your PostgreSQL database connection string
conn_str = f'postgresql://{USERNAME}:{PASSWORD}@{SERVER}/{DATABASE}'

# Establish a connection to the PostgreSQL database
engine = create_engine(conn_str)

Inspector = inspect(engine)

# Create a sessionmaker to handle transactions
Session = sessionmaker(bind=engine)

# Loop through each DataFrame in data_frames list
for df in data_frames:
    # Extract the file name from the DataFrame
    table_name = df['file_name'].iloc[0].split('.')[0]

    # Begin a transaction
    with Session.begin() as session:
        # Check if the table already exists in the database
        table_exists = Inspector.has_table(table_name)

        if not table_exists:
            # If the table does not exist, create it
            df.head(0).to_sql(table_name, engine, index=False)  # Create empty table structure

        # Load the DataFrame into the database table
        df.to_sql(table_name, engine, if_exists='append', index=False)  # Append data to the table

print("ETL process completed successfully.")

# %% [markdown]
# EXTRACT, TRANSFORM & LOAD FROM DATABASE TO WAREHOUSE

# %% [markdown]
# # Transformation

# %% [markdown]
# <b>1. Handle Duplicates:</b>
#
# Are there duplicate rows in the dataset that need to be removed?
#
# How will the removal of duplicates impact the analysis or modeling tasks?

# %%
def handle_duplicates(data_frames):
    """
    Remove duplicates from each DataFrame in the list.
    
    Parameters:
        data_frames (list): List of DataFrames.
        
    Returns:
        list: List of DataFrames with duplicates removed.
    """
    cleansed_data_frames = []
    for df in data_frames:
        cleansed_data_frames.append(df.drop_duplicates())
    return cleansed_data_frames

# %% [markdown]
# <b>2. Handle Missing Values:</b>
#
# Are there columns with over 90% missing values and rows with 100% missing values in the dataset?
#
# How will the removal of duplicates impact the analysis or modeling tasks?

# %%
def handle_missing_values(data_frames, column_threshold=0.9):
    """
    Handle missing values in a list of DataFrames by dropping columns with over 90% missing values
    and rows that are 100% null.

    Parameters:
        data_frames (list): List of pandas DataFrames.
        column_threshold (float): Threshold for dropping columns based on the proportion of missing values.
    
    Returns:
        cleaned_data_frames (list): List of DataFrames with missing values handled.
    """
    cleaned_data_frames = []

    for df in data_frames:

        # Make a copy of the DataFrame
        df = df.copy()
        
        # Drop columns with over 90% missing values
        df.dropna(axis=1, thresh=int(column_threshold * len(df)), inplace=True)
        
        # Drop rows that are 100% null
        df.dropna(axis=0, how='all', inplace=True)
        
        # Reset index
        df.reset_index(drop=True, inplace=True)

        cleaned_data_frames.append(df)

    return cleaned_data_frames

# %% [markdown]
# <b>3. Data Type:</b>
#
# What are the data types of the values? (Numeric, categorical, or other?)
#
# If numeric, are they continuous or discrete?

# %%
def classify_datatypes(dataframes):
    """
    Classify columns in a list of DataFrames into different data types: numeric, datetime, date, and categorical.

    Parameters:
        dataframes (list): A list of pandas DataFrames.

    Returns:
        numeric_columns_all (list): List of columns classified as numeric across all DataFrames.
        datetime_columns_all (list): List of columns classified as datetime across all DataFrames.
        date_columns_all (list): List of columns classified as date across all DataFrames.
        categorical_columns_all (list): List of columns classified as categorical across all DataFrames.
    """
    numeric_columns_all = []
    datetime_columns_all = []
    date_columns_all = []
    categorical_columns_all = []

    for df in dataframes:
        numeric_columns, datetime_columns, date_columns, categorical_columns = [], [], [], []

        for col in df.columns:
            if df[col].dtype in ['float64', 'int64']:
                numeric_columns.append(col)
            elif df[col].astype(str).str.match(r'\d+/\d+/\d+ \d+:\d+:\d+ [AP]M').all():
                datetime_columns.append(col)
            elif df[col].astype(str).str.match(r'\d+/\d+/\d+').all():
                date_columns.append(col)
            else:
                categorical_columns.append(col)

        numeric_columns_all.extend(numeric_columns)
        datetime_columns_all.extend(datetime_columns)
        date_columns_all.extend(date_columns)
        categorical_columns_all.extend(categorical_columns)

    return numeric_columns_all, datetime_columns_all, date_columns_all, categorical_columns_all, data_frames

# %% [markdown]
# <b>4. Data Context:</b>
#
# What do the values represent? (Measurements, counts, percentages, etc.)
#
# What is the context or domain of the data?

# %%
def classify_numeric_columns(data_frames, numeric_columns_all, threshold=0.06):
    """
    Classify numeric columns in a list of DataFrames into count columns and measurement columns.
    
    Parameters:
        data_frames (list): List of DataFrames.
        numeric_columns_all (list): List of all numeric columns across all DataFrames.
        threshold (float): Threshold to differentiate count columns from measurement columns based on the proportion of unique values.
                           Columns with a proportion of unique values less than or equal to the threshold are classified as count columns.
    
    Returns:
        count_columns_all (list): List of all count columns across all DataFrames.
        measurement_columns_all (list): List of all measurement columns across all DataFrames.
    """

    count_columns_all = []
    measurement_columns_all = []

    for df in data_frames:
        count_columns, measurement_columns = [], []

        for col in numeric_columns_all:
            if col in df.columns:  # Check if column exists in DataFrame
                unique_ratio = df[col].nunique() / len(df[col])
                print(f'unique_ratio: {unique_ratio} for {col}')
                
                if unique_ratio <= 0.06:
                    count_columns.append(col)
                    print(f'{col} from unique_ratio')
                    print(f'{count_columns} from count_columns')
                
                elif col.endswith('Id'):
                    count_columns.append(col)
                    print(f'{col} from endswith Id')
                    print(f'{count_columns} from count_columns')

                else:
                    measurement_columns.append(col)
                         
    count_columns_all.extend(count_columns)
    measurement_columns_all.extend(measurement_columns)

    return count_columns_all, measurement_columns_all, data_frames

# %%
#chain the functions

# 1. clean duplicates
cleansed_data_frames_duplicates = handle_duplicates(data_frames)

# 2. clean missing values using the cleaned data frames from duplicates
cleansed_data_frames_missing_values = handle_missing_values(cleansed_data_frames_duplicates)

# 3. Unpack the returned tuple and classify datatypes using cleansed data_frames from missing values
numeric_columns_all, datetime_columns_all, date_columns_all, categorical_columns_all, cleansed_data_frames_datatypes = classify_datatypes(cleansed_data_frames_missing_values)

# 4. Categorize numeric columns into count and measurements using unpacked cleansed data_frames from classify_datatypes function
count_columns_all, measurement_columns_all, cleansed_data_frames_classify_numbers = classify_numeric_columns(cleansed_data_frames_datatypes, numeric_columns_all)
# Out:
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id'] from count_columns
# unique_ratio: 0.8957446808510638 for TotalSteps
# unique_ratio: 0.6542553191489362 for TotalDistance
# unique_ratio: 0.652127659574468 for TrackerDistance
# unique_ratio: 0.02021276595744681 for LoggedActivitiesDistance
# LoggedActivitiesDistance from unique_ratio
# ['Id', 'LoggedActivitiesDistance'] from count_columns
# unique_ratio: 0.35425531914893615 for VeryActiveDistance
# unique_ratio: 0.22446808510638297 for ModeratelyActiveDistance
# unique_ratio: 0.5223404255319148 for LightActiveDistance
# unique_ratio: 0.009574468085106383 for SedentaryActiveDistance
# SedentaryActiveDistance from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance'] from count_columns
# unique_ratio: 0.12978723404255318 for VeryActiveMinutes
# unique_ratio: 0.08617021276595745 for FairlyActiveMinutes
# unique_ratio: 0.35638297872340424 for LightlyActiveMinutes
# unique_ratio: 0.5840425531914893 for SedentaryMinutes
# unique_ratio: 0.7808510638297872 for Calories
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id'] from count_columns
# unique_ratio: 0.7808510638297872 for Calories
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id'] from count_columns
# unique_ratio: 0.5840425531914893 for SedentaryMinutes
# unique_ratio: 0.35638297872340424 for LightlyActiveMinutes
# unique_ratio: 0.08617021276595745 for FairlyActiveMinutes
# unique_ratio: 0.12978723404255318 for VeryActiveMinutes
# unique_ratio: 0.009574468085106383 for SedentaryActiveDistance
# SedentaryActiveDistance from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance'] from count_columns
# unique_ratio: 0.5223404255319148 for LightActiveDistance
# unique_ratio: 0.22446808510638297 for ModeratelyActiveDistance
# unique_ratio: 0.35425531914893615 for VeryActiveDistance
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.7808510638297872 for Calories
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.7808510638297872 for Calories
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'LoggedActivitiesDistance', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id'] from count_columns
# unique_ratio: 0.7808510638297872 for Calories
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id'] from count_columns
# unique_ratio: 0.7808510638297872 for Calories
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.7808510638297872 for Calories
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.7808510638297872 for Calories
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id'] from count_columns
# unique_ratio: 0.35425531914893615 for VeryActiveDistance
# unique_ratio: 0.22446808510638297 for ModeratelyActiveDistance
# unique_ratio: 0.5223404255319148 for LightActiveDistance
# unique_ratio: 0.009574468085106383 for SedentaryActiveDistance
# SedentaryActiveDistance from unique_ratio
# ['Id', 'SedentaryActiveDistance'] from count_columns
# unique_ratio: 0.12978723404255318 for VeryActiveMinutes
# unique_ratio: 0.08617021276595745 for FairlyActiveMinutes
# unique_ratio: 0.35638297872340424 for LightlyActiveMinutes
# unique_ratio: 0.5840425531914893 for SedentaryMinutes
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id'] from count_columns
# unique_ratio: 0.5840425531914893 for SedentaryMinutes
# unique_ratio: 0.35638297872340424 for LightlyActiveMinutes
# unique_ratio: 0.08617021276595745 for FairlyActiveMinutes
# unique_ratio: 0.12978723404255318 for VeryActiveMinutes
# unique_ratio: 0.009574468085106383 for SedentaryActiveDistance
# SedentaryActiveDistance from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance'] from count_columns
# unique_ratio: 0.5223404255319148 for LightActiveDistance
# unique_ratio: 0.22446808510638297 for ModeratelyActiveDistance
# unique_ratio: 0.35425531914893615 for VeryActiveDistance
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'SedentaryActiveDistance', 'Id', 'Id', 'SedentaryActiveDistance', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.8957446808510638 for StepTotal
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.8957446808510638 for StepTotal
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.035106382978723406 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 6.764216329301377e-05 for Value
# Value from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Value'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Value', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Value', 'Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Value', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Value', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Value', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Value', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Value', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Value', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Value', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Value', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Value', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Value', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 5.636846941084481e-06 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Value', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id'] from count_columns
# unique_ratio: 0.02000090501832662 for Calories
# Calories from unique_ratio
# ['Id', 'Calories'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id'] from count_columns
# unique_ratio: 0.02000090501832662 for Calories
# Calories from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.02000090501832662 for Calories
# Calories from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.02000090501832662 for Calories
# Calories from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.007918910357934749 for TotalIntensity
# TotalIntensity from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalIntensity'] from count_columns
# unique_ratio: 0.007918910357934749 for AverageIntensity
# AverageIntensity from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalIntensity', 'AverageIntensity'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalIntensity', 'AverageIntensity', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalIntensity', 'AverageIntensity', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalIntensity', 'AverageIntensity', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalIntensity', 'AverageIntensity', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalIntensity', 'AverageIntensity', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalIntensity', 'AverageIntensity', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalIntensity', 'AverageIntensity', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalIntensity', 'AverageIntensity', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalIntensity', 'AverageIntensity', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalIntensity', 'AverageIntensity', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalIntensity', 'AverageIntensity', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.10054753608760578 for StepTotal
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.10054753608760578 for StepTotal
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0014932802389248383 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id'] from count_columns
# unique_ratio: 0.0029760557642692256 for Calories
# Calories from unique_ratio
# ['Id', 'Calories'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id'] from count_columns
# unique_ratio: 0.0029760557642692256 for Calories
# Calories from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0029760557642692256 for Calories
# Calories from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0029760557642692256 for Calories
# Calories from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 2.4894763047118996e-05 for Id
# Id from unique_ratio
# ['Id', 'Calories', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Calories', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0015246015246015245 for Id
# Id from unique_ratio
# ['Id'] from count_columns
# unique_ratio: 0.0015246015246015245 for Id
# Id from unique_ratio
# ['Id', 'Id'] from count_columns
# unique_ratio: 0.0015246015246015245 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0015246015246015245 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0015246015246015245 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0015246015246015245 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0015246015246015245 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0015246015246015245 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0015246015246015245 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.0015246015246015245 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.058396858396858396 for Calories00
# Calories00 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00'] from count_columns
# unique_ratio: 0.05714945714945715 for Calories01
# Calories01 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01'] from count_columns
# unique_ratio: 0.05816585816585817 for Calories02
# Calories02 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02'] from count_columns
# unique_ratio: 0.05862785862785863 for Calories03
# Calories03 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03'] from count_columns
# unique_ratio: 0.05932085932085932 for Calories04
# Calories04 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04'] from count_columns
# unique_ratio: 0.058997458997459 for Calories05
# Calories05 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05'] from count_columns
# unique_ratio: 0.05885885885885886 for Calories06
# Calories06 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06'] from count_columns
# unique_ratio: 0.058905058905058906 for Calories07
# Calories07 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07'] from count_columns
# unique_ratio: 0.058766458766458765 for Calories08
# Calories08 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08'] from count_columns
# unique_ratio: 0.05761145761145761 for Calories09
# Calories09 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09'] from count_columns
# unique_ratio: 0.05936705936705937 for Calories10
# Calories10 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10'] from count_columns
# unique_ratio: 0.05784245784245784 for Calories11
# Calories11 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11'] from count_columns
# unique_ratio: 0.05728805728805729 for Calories12
# Calories12 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12'] from count_columns
# unique_ratio: 0.05747285747285747 for Calories13
# Calories13 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13'] from count_columns
# unique_ratio: 0.05816585816585817 for Calories14
# Calories14 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14'] from count_columns
# unique_ratio: 0.058905058905058906 for Calories15
# Calories15 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15'] from count_columns
# unique_ratio: 0.05784245784245784 for Calories16
# Calories16 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16'] from count_columns
# unique_ratio: 0.05775005775005775 for Calories17
# Calories17 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17'] from count_columns
# unique_ratio: 0.058997458997459 for Calories18
# Calories18 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18'] from count_columns
# unique_ratio: 0.05798105798105798 for Calories19
# Calories19 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19'] from count_columns
# unique_ratio: 0.05724185724185724 for Calories20
# Calories20 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20'] from count_columns
# unique_ratio: 0.05793485793485793 for Calories21
# Calories21 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21'] from count_columns
# unique_ratio: 0.05793485793485793 for Calories22
# Calories22 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21', 'Calories22'] from count_columns
# unique_ratio: 0.05724185724185724 for Calories23
# Calories23 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21', 'Calories22', 'Calories23'] from count_columns
# unique_ratio: 0.05691845691845692 for Calories24
# Calories24 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21', 'Calories22', 'Calories23', 'Calories24'] from count_columns
# unique_ratio: 0.05793485793485793 for Calories25
# Calories25 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21', 'Calories22', 'Calories23', 'Calories24', 'Calories25'] from count_columns
# unique_ratio: 0.05733425733425734 for Calories26
# Calories26 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21', 'Calories22', 'Calories23', 'Calories24', 'Calories25', 'Calories26'] from count_columns
# unique_ratio: 0.05848925848925849 for Calories27
# Calories27 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21', 'Calories22', 'Calories23', 'Calories24', 'Calories25', 'Calories26', 'Calories27'] from count_columns
# unique_ratio: 0.05751905751905752 for Calories28
# Calories28 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21', 'Calories22', 'Calories23', 'Calories24', 'Calories25', 'Calories26', 'Calories27', 'Calories28'] from count_columns
# unique_ratio: 0.05798105798105798 for Calories29
# Calories29 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21', 'Calories22', 'Calories23', 'Calories24', 'Calories25', 'Calories26', 'Calories27', 'Calories28', 'Calories29'] from count_columns
# unique_ratio: 0.0577962577962578 for Calories30
# Calories30 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21', 'Calories22', 'Calories23', 'Calories24', 'Calories25', 'Calories26', 'Calories27', 'Calories28', 'Calories29', 'Calories30'] from count_columns
# unique_ratio: 0.0583044583044583 for Calories31
# Calories31 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21', 'Calories22', 'Calories23', 'Calories24', 'Calories25', 'Calories26', 'Calories27', 'Calories28', 'Calories29', 'Calories30', 'Calories31'] from count_columns
# unique_ratio: 0.058396858396858396 for Calories32
# Calories32 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21', 'Calories22', 'Calories23', 'Calories24', 'Calories25', 'Calories26', 'Calories27', 'Calories28', 'Calories29', 'Calories30', 'Calories31', 'Calories32'] from count_columns
# unique_ratio: 0.05918225918225918 for Calories33
# Calories33 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21', 'Calories22', 'Calories23', 'Calories24', 'Calories25', 'Calories26', 'Calories27', 'Calories28', 'Calories29', 'Calories30', 'Calories31', 'Calories32', 'Calories33'] from count_columns
# unique_ratio: 0.05802725802725803 for Calories34
# Calories34 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21', 'Calories22', 'Calories23', 'Calories24', 'Calories25', 'Calories26', 'Calories27', 'Calories28', 'Calories29', 'Calories30', 'Calories31', 'Calories32', 'Calories33', 'Calories34'] from count_columns
# unique_ratio: 0.05816585816585817 for Calories35
# Calories35 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Calories00', 'Calories01', 'Calories02', 'Calories03', 'Calories04', 'Calories05', 'Calories06', 'Calories07', 'Calories08', 'Calories09', 'Calories10', 'Calories11', 'Calories12', 'Calories13', 'Calories14', 'Calories15', 'Calories16', 'Calories17', 'Calories18', 'Calories19', 'Calories20', 'Calories21', 'Calories22', 'Calories23', 'Calories24', 'Calories25', 'Calories26', 'Calories27', 'Calories28', 'Calories29', 'Calories30', 'Calories31', 'Calories32', 'Calories33', 'Calories34', 'Calories35'] from count_columns
# ...
# unique_ratio: 0.0072996072996072995 for Steps50
# Steps50 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Steps00', 'Steps01', 'Steps02', 'Steps03', 'Steps04', 'Steps05', 'Steps06', 'Steps07', 'Steps08', 'Steps09', 'Steps10', 'Steps11', 'Steps12', 'Steps13', 'Steps14', 'Steps15', 'Steps16', 'Steps17', 'Steps18', 'Steps19', 'Steps20', 'Steps21', 'Steps22', 'Steps23', 'Steps24', 'Steps25', 'Steps26', 'Steps27', 'Steps28', 'Steps29', 'Steps30', 'Steps31', 'Steps32', 'Steps33', 'Steps34', 'Steps35', 'Steps36', 'Steps37', 'Steps38', 'Steps39', 'Steps40', 'Steps41', 'Steps42', 'Steps43', 'Steps44', 'Steps45', 'Steps46', 'Steps47', 'Steps48', 'Steps49', 'Steps50'] from count_columns
# unique_ratio: 0.007253407253407253 for Steps51
# Steps51 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Steps00', 'Steps01', 'Steps02', 'Steps03', 'Steps04', 'Steps05', 'Steps06', 'Steps07', 'Steps08', 'Steps09', 'Steps10', 'Steps11', 'Steps12', 'Steps13', 'Steps14', 'Steps15', 'Steps16', 'Steps17', 'Steps18', 'Steps19', 'Steps20', 'Steps21', 'Steps22', 'Steps23', 'Steps24', 'Steps25', 'Steps26', 'Steps27', 'Steps28', 'Steps29', 'Steps30', 'Steps31', 'Steps32', 'Steps33', 'Steps34', 'Steps35', 'Steps36', 'Steps37', 'Steps38', 'Steps39', 'Steps40', 'Steps41', 'Steps42', 'Steps43', 'Steps44', 'Steps45', 'Steps46', 'Steps47', 'Steps48', 'Steps49', 'Steps50', 'Steps51'] from count_columns
# unique_ratio: 0.006976206976206976 for Steps52
# Steps52 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Steps00', 'Steps01', 'Steps02', 'Steps03', 'Steps04', 'Steps05', 'Steps06', 'Steps07', 'Steps08', 'Steps09', 'Steps10', 'Steps11', 'Steps12', 'Steps13', 'Steps14', 'Steps15', 'Steps16', 'Steps17', 'Steps18', 'Steps19', 'Steps20', 'Steps21', 'Steps22', 'Steps23', 'Steps24', 'Steps25', 'Steps26', 'Steps27', 'Steps28', 'Steps29', 'Steps30', 'Steps31', 'Steps32', 'Steps33', 'Steps34', 'Steps35', 'Steps36', 'Steps37', 'Steps38', 'Steps39', 'Steps40', 'Steps41', 'Steps42', 'Steps43', 'Steps44', 'Steps45', 'Steps46', 'Steps47', 'Steps48', 'Steps49', 'Steps50', 'Steps51', 'Steps52'] from count_columns
# unique_ratio: 0.007253407253407253 for Steps53
# Steps53 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Steps00', 'Steps01', 'Steps02', 'Steps03', 'Steps04', 'Steps05', 'Steps06', 'Steps07', 'Steps08', 'Steps09', 'Steps10', 'Steps11', 'Steps12', 'Steps13', 'Steps14', 'Steps15', 'Steps16', 'Steps17', 'Steps18', 'Steps19', 'Steps20', 'Steps21', 'Steps22', 'Steps23', 'Steps24', 'Steps25', 'Steps26', 'Steps27', 'Steps28', 'Steps29', 'Steps30', 'Steps31', 'Steps32', 'Steps33', 'Steps34', 'Steps35', 'Steps36', 'Steps37', 'Steps38', 'Steps39', 'Steps40', 'Steps41', 'Steps42', 'Steps43', 'Steps44', 'Steps45', 'Steps46', 'Steps47', 'Steps48', 'Steps49', 'Steps50', 'Steps51', 'Steps52', 'Steps53'] from count_columns
# unique_ratio: 0.007345807345807346 for Steps54
# Steps54 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Steps00', 'Steps01', 'Steps02', 'Steps03', 'Steps04', 'Steps05', 'Steps06', 'Steps07', 'Steps08', 'Steps09', 'Steps10', 'Steps11', 'Steps12', 'Steps13', 'Steps14', 'Steps15', 'Steps16', 'Steps17', 'Steps18', 'Steps19', 'Steps20', 'Steps21', 'Steps22', 'Steps23', 'Steps24', 'Steps25', 'Steps26', 'Steps27', 'Steps28', 'Steps29', 'Steps30', 'Steps31', 'Steps32', 'Steps33', 'Steps34', 'Steps35', 'Steps36', 'Steps37', 'Steps38', 'Steps39', 'Steps40', 'Steps41', 'Steps42', 'Steps43', 'Steps44', 'Steps45', 'Steps46', 'Steps47', 'Steps48', 'Steps49', 'Steps50', 'Steps51', 'Steps52', 'Steps53', 'Steps54'] from count_columns
# unique_ratio: 0.007161007161007161 for Steps55
# Steps55 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Steps00', 'Steps01', 'Steps02', 'Steps03', 'Steps04', 'Steps05', 'Steps06', 'Steps07', 'Steps08', 'Steps09', 'Steps10', 'Steps11', 'Steps12', 'Steps13', 'Steps14', 'Steps15', 'Steps16', 'Steps17', 'Steps18', 'Steps19', 'Steps20', 'Steps21', 'Steps22', 'Steps23', 'Steps24', 'Steps25', 'Steps26', 'Steps27', 'Steps28', 'Steps29', 'Steps30', 'Steps31', 'Steps32', 'Steps33', 'Steps34', 'Steps35', 'Steps36', 'Steps37', 'Steps38', 'Steps39', 'Steps40', 'Steps41', 'Steps42', 'Steps43', 'Steps44', 'Steps45', 'Steps46', 'Steps47', 'Steps48', 'Steps49', 'Steps50', 'Steps51', 'Steps52', 'Steps53', 'Steps54', 'Steps55'] from count_columns
# unique_ratio: 0.0072996072996072995 for Steps56
# Steps56 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Steps00', 'Steps01', 'Steps02', 'Steps03', 'Steps04', 'Steps05', 'Steps06', 'Steps07', 'Steps08', 'Steps09', 'Steps10', 'Steps11', 'Steps12', 'Steps13', 'Steps14', 'Steps15', 'Steps16', 'Steps17', 'Steps18', 'Steps19', 'Steps20', 'Steps21', 'Steps22', 'Steps23', 'Steps24', 'Steps25', 'Steps26', 'Steps27', 'Steps28', 'Steps29', 'Steps30', 'Steps31', 'Steps32', 'Steps33', 'Steps34', 'Steps35', 'Steps36', 'Steps37', 'Steps38', 'Steps39', 'Steps40', 'Steps41', 'Steps42', 'Steps43', 'Steps44', 'Steps45', 'Steps46', 'Steps47', 'Steps48', 'Steps49', 'Steps50', 'Steps51', 'Steps52', 'Steps53', 'Steps54', 'Steps55', 'Steps56'] from count_columns
# unique_ratio: 0.007345807345807346 for Steps57
# Steps57 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Steps00', 'Steps01', 'Steps02', 'Steps03', 'Steps04', 'Steps05', 'Steps06', 'Steps07', 'Steps08', 'Steps09', 'Steps10', 'Steps11', 'Steps12', 'Steps13', 'Steps14', 'Steps15', 'Steps16', 'Steps17', 'Steps18', 'Steps19', 'Steps20', 'Steps21', 'Steps22', 'Steps23', 'Steps24', 'Steps25', 'Steps26', 'Steps27', 'Steps28', 'Steps29', 'Steps30', 'Steps31', 'Steps32', 'Steps33', 'Steps34', 'Steps35', 'Steps36', 'Steps37', 'Steps38', 'Steps39', 'Steps40', 'Steps41', 'Steps42', 'Steps43', 'Steps44', 'Steps45', 'Steps46', 'Steps47', 'Steps48', 'Steps49', 'Steps50', 'Steps51', 'Steps52', 'Steps53', 'Steps54', 'Steps55', 'Steps56', 'Steps57'] from count_columns
# unique_ratio: 0.007207207207207207 for Steps58
# Steps58 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Steps00', 'Steps01', 'Steps02', 'Steps03', 'Steps04', 'Steps05', 'Steps06', 'Steps07', 'Steps08', 'Steps09', 'Steps10', 'Steps11', 'Steps12', 'Steps13', 'Steps14', 'Steps15', 'Steps16', 'Steps17', 'Steps18', 'Steps19', 'Steps20', 'Steps21', 'Steps22', 'Steps23', 'Steps24', 'Steps25', 'Steps26', 'Steps27', 'Steps28', 'Steps29', 'Steps30', 'Steps31', 'Steps32', 'Steps33', 'Steps34', 'Steps35', 'Steps36', 'Steps37', 'Steps38', 'Steps39', 'Steps40', 'Steps41', 'Steps42', 'Steps43', 'Steps44', 'Steps45', 'Steps46', 'Steps47', 'Steps48', 'Steps49', 'Steps50', 'Steps51', 'Steps52', 'Steps53', 'Steps54', 'Steps55', 'Steps56', 'Steps57', 'Steps58'] from count_columns
# unique_ratio: 0.007114807114807115 for Steps59
# Steps59 from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Steps00', 'Steps01', 'Steps02', 'Steps03', 'Steps04', 'Steps05', 'Steps06', 'Steps07', 'Steps08', 'Steps09', 'Steps10', 'Steps11', 'Steps12', 'Steps13', 'Steps14', 'Steps15', 'Steps16', 'Steps17', 'Steps18', 'Steps19', 'Steps20', 'Steps21', 'Steps22', 'Steps23', 'Steps24', 'Steps25', 'Steps26', 'Steps27', 'Steps28', 'Steps29', 'Steps30', 'Steps31', 'Steps32', 'Steps33', 'Steps34', 'Steps35', 'Steps36', 'Steps37', 'Steps38', 'Steps39', 'Steps40', 'Steps41', 'Steps42', 'Steps43', 'Steps44', 'Steps45', 'Steps46', 'Steps47', 'Steps48', 'Steps49', 'Steps50', 'Steps51', 'Steps52', 'Steps53', 'Steps54', 'Steps55', 'Steps56', 'Steps57', 'Steps58', 'Steps59'] from count_columns
# unique_ratio: 0.0015246015246015245 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Steps00', 'Steps01', 'Steps02', 'Steps03', 'Steps04', 'Steps05', 'Steps06', 'Steps07', 'Steps08', 'Steps09', 'Steps10', 'Steps11', 'Steps12', 'Steps13', 'Steps14', 'Steps15', 'Steps16', 'Steps17', 'Steps18', 'Steps19', 'Steps20', 'Steps21', 'Steps22', 'Steps23', 'Steps24', 'Steps25', 'Steps26', 'Steps27', 'Steps28', 'Steps29', 'Steps30', 'Steps31', 'Steps32', 'Steps33', 'Steps34', 'Steps35', 'Steps36', 'Steps37', 'Steps38', 'Steps39', 'Steps40', 'Steps41', 'Steps42', 'Steps43', 'Steps44', 'Steps45', 'Steps46', 'Steps47', 'Steps48', 'Steps49', 'Steps50', 'Steps51', 'Steps52', 'Steps53', 'Steps54', 'Steps55', 'Steps56', 'Steps57', 'Steps58', 'Steps59', 'Id'] from count_columns
# unique_ratio: 0.0015246015246015245 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Steps00', 'Steps01', 'Steps02', 'Steps03', 'Steps04', 'Steps05', 'Steps06', 'Steps07', 'Steps08', 'Steps09', 'Steps10', 'Steps11', 'Steps12', 'Steps13', 'Steps14', 'Steps15', 'Steps16', 'Steps17', 'Steps18', 'Steps19', 'Steps20', 'Steps21', 'Steps22', 'Steps23', 'Steps24', 'Steps25', 'Steps26', 'Steps27', 'Steps28', 'Steps29', 'Steps30', 'Steps31', 'Steps32', 'Steps33', 'Steps34', 'Steps35', 'Steps36', 'Steps37', 'Steps38', 'Steps39', 'Steps40', 'Steps41', 'Steps42', 'Steps43', 'Steps44', 'Steps45', 'Steps46', 'Steps47', 'Steps48', 'Steps49', 'Steps50', 'Steps51', 'Steps52', 'Steps53', 'Steps54', 'Steps55', 'Steps56', 'Steps57', 'Steps58', 'Steps59', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.007263922518159807 for TotalSleepRecords
# TotalSleepRecords from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalSleepRecords'] from count_columns
# unique_ratio: 0.6198547215496368 for TotalMinutesAsleep
# unique_ratio: 0.585956416464891 for TotalTimeInBed
# unique_ratio: 0.05811138014527845 for Id
# Id from unique_ratio
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'TotalSleepRecords', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.11940298507462686 for Id
# Id from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id'] from count_columns
# unique_ratio: 0.5074626865671642 for WeightKg
# unique_ratio: 0.5074626865671642 for WeightPounds
# unique_ratio: 0.5373134328358209 for BMI
# unique_ratio: 0.835820895522388 for LogId
# LogId from endswith Id
# ['Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'Id', 'LogId'] from count_columns

# %%
total_columns = 0
for df in cleansed_data_frames_classify_numbers:
    total_columns += len(df.columns)
print(total_columns)
# Out:
# 277

# %%
len(count_columns_all)
# Out:
# 4302

# %%
len(measurement_columns_all)
# Out:
# 4302

# %%
len(numeric_columns_all)
# Out:
# 239

# %%
print(len(datetime_columns_all))
print(len(date_columns_all))
print(len(categorical_columns_all))
# Out:
# 14
# 4
# 19

# %%
count_columns_all
# Out:
# ['Id',
#  'Id',
#  'Id',
#  'Id',
#  'Id',
#  'Id',
#  'Id',
#  'Id',
#  'Id',
#  'Id',
#  'Id',
#  'Id',
#  'Id',
#  'Id',
#  'Id',
#  'Id',
#  'Id',
#  'Id',
#  'LogId']

# %%
numeric_columns_all
# Out:
# ['Id',
#  'TotalSteps',
#  'TotalDistance',
#  'TrackerDistance',
#  'LoggedActivitiesDistance',
#  'VeryActiveDistance',
#  'ModeratelyActiveDistance',
#  'LightActiveDistance',
#  'SedentaryActiveDistance',
#  'VeryActiveMinutes',
#  'FairlyActiveMinutes',
#  'LightlyActiveMinutes',
#  'SedentaryMinutes',
#  'Calories',
#  'Id',
#  'Calories',
#  'Id',
#  'SedentaryMinutes',
#  'LightlyActiveMinutes',
#  'FairlyActiveMinutes',
#  'VeryActiveMinutes',
#  'SedentaryActiveDistance',
#  'LightActiveDistance',
#  'ModeratelyActiveDistance',
#  'VeryActiveDistance',
#  'Id',
#  'StepTotal',
#  'Id',
#  'Value',
#  'Id',
#  'Calories',
#  'Id',
#  'TotalIntensity',
#  'AverageIntensity',
#  'Id',
#  'StepTotal',
#  'Id',
#  'Calories',
#  'Id',
#  'Calories00',
#  'Calories01',
#  'Calories02',
#  'Calories03',
#  'Calories04',
#  'Calories05',
#  'Calories06',
#  'Calories07',
#  'Calories08',
#  'Calories09',
#  'Calories10',
#  'Calories11',
#  'Calories12',
#  'Calories13',
#  'Calories14',
#  'Calories15',
#  'Calories16',
#  'Calories17',
#  'Calories18',
#  'Calories19',
#  'Calories20',
#  'Calories21',
#  'Calories22',
#  'Calories23',
#  'Calories24',
#  'Calories25',
#  'Calories26',
#  'Calories27',
#  'Calories28',
#  'Calories29',
#  'Calories30',
#  'Calories31',
#  'Calories32',
#  'Calories33',
#  'Calories34',
#  'Calories35',
#  'Calories36',
#  'Calories37',
#  'Calories38',
#  'Calories39',
#  'Calories40',
#  'Calories41',
#  'Calories42',
#  'Calories43',
#  'Calories44',
#  'Calories45',
#  'Calories46',
#  'Calories47',
#  'Calories48',
#  'Calories49',
#  'Calories50',
#  'Calories51',
#  'Calories52',
#  'Calories53',
#  'Calories54',
#  'Calories55',
#  'Calories56',
#  'Calories57',
#  'Calories58',
#  'Calories59',
#  'Id',
#  'Intensity',
#  'Id',
#  'Intensity00',
#  'Intensity01',
#  'Intensity02',
#  'Intensity03',
#  'Intensity04',
#  'Intensity05',
#  'Intensity06',
#  'Intensity07',
#  'Intensity08',
#  'Intensity09',
#  'Intensity10',
#  'Intensity11',
#  'Intensity12',
#  'Intensity13',
#  'Intensity14',
#  'Intensity15',
#  'Intensity16',
#  'Intensity17',
#  'Intensity18',
#  'Intensity19',
#  'Intensity20',
#  'Intensity21',
#  'Intensity22',
#  'Intensity23',
#  'Intensity24',
#  'Intensity25',
#  'Intensity26',
#  'Intensity27',
#  'Intensity28',
#  'Intensity29',
#  'Intensity30',
#  'Intensity31',
#  'Intensity32',
#  'Intensity33',
#  'Intensity34',
#  'Intensity35',
#  'Intensity36',
#  'Intensity37',
#  'Intensity38',
#  'Intensity39',
#  'Intensity40',
#  'Intensity41',
#  'Intensity42',
#  'Intensity43',
#  'Intensity44',
#  'Intensity45',
#  'Intensity46',
#  'Intensity47',
#  'Intensity48',
#  'Intensity49',
#  'Intensity50',
#  'Intensity51',
#  'Intensity52',
#  'Intensity53',
#  'Intensity54',
#  'Intensity55',
#  'Intensity56',
#  'Intensity57',
#  'Intensity58',
#  'Intensity59',
#  'Id',
#  'METs',
#  'Id',
#  'value',
#  'logId',
#  'Id',
#  'Steps',
#  'Id',
#  'Steps00',
#  'Steps01',
#  'Steps02',
#  'Steps03',
#  'Steps04',
#  'Steps05',
#  'Steps06',
#  'Steps07',
#  'Steps08',
#  'Steps09',
#  'Steps10',
#  'Steps11',
#  'Steps12',
#  'Steps13',
#  'Steps14',
#  'Steps15',
#  'Steps16',
#  'Steps17',
#  'Steps18',
#  'Steps19',
#  'Steps20',
#  'Steps21',
#  'Steps22',
#  'Steps23',
#  'Steps24',
#  'Steps25',
#  'Steps26',
#  'Steps27',
#  'Steps28',
#  'Steps29',
#  'Steps30',
#  'Steps31',
#  'Steps32',
#  'Steps33',
#  'Steps34',
#  'Steps35',
#  'Steps36',
#  'Steps37',
#  'Steps38',
#  'Steps39',
#  'Steps40',
#  'Steps41',
#  'Steps42',
#  'Steps43',
#  'Steps44',
#  'Steps45',
#  'Steps46',
#  'Steps47',
#  'Steps48',
#  'Steps49',
#  'Steps50',
#  'Steps51',
#  'Steps52',
#  'Steps53',
#  'Steps54',
#  'Steps55',
#  'Steps56',
#  'Steps57',
#  'Steps58',
#  'Steps59',
#  'Id',
#  'TotalSleepRecords',
#  'TotalMinutesAsleep',
#  'TotalTimeInBed',
#  'Id',
#  'WeightKg',
#  'WeightPounds',
#  'BMI',
#  'LogId']

# %%
measurement_columns_all
# Out:
# ['TotalSteps',
#  'TotalDistance',
#  'TrackerDistance',
#  'LoggedActivitiesDistance',
#  'VeryActiveDistance',
#  'ModeratelyActiveDistance',
#  'LightActiveDistance',
#  'SedentaryActiveDistance',
#  'VeryActiveMinutes',
#  'FairlyActiveMinutes',
#  'LightlyActiveMinutes',
#  'SedentaryMinutes',
#  'Calories',
#  'Calories',
#  'SedentaryMinutes',
#  'LightlyActiveMinutes',
#  'FairlyActiveMinutes',
#  'VeryActiveMinutes',
#  'SedentaryActiveDistance',
#  'LightActiveDistance',
#  'ModeratelyActiveDistance',
#  'VeryActiveDistance',
#  'StepTotal',
#  'Value',
#  'Calories',
#  'TotalIntensity',
#  'AverageIntensity',
#  'StepTotal',
#  'Calories',
#  'Calories00',
#  'Calories01',
#  'Calories02',
#  'Calories03',
#  'Calories04',
#  'Calories05',
#  'Calories06',
#  'Calories07',
#  'Calories08',
#  'Calories09',
#  'Calories10',
#  'Calories11',
#  'Calories12',
#  'Calories13',
#  'Calories14',
#  'Calories15',
#  'Calories16',
#  'Calories17',
#  'Calories18',
#  'Calories19',
#  'Calories20',
#  'Calories21',
#  'Calories22',
#  'Calories23',
#  'Calories24',
#  'Calories25',
#  'Calories26',
#  'Calories27',
#  'Calories28',
#  'Calories29',
#  'Calories30',
#  'Calories31',
#  'Calories32',
#  'Calories33',
#  'Calories34',
#  'Calories35',
#  'Calories36',
#  'Calories37',
#  'Calories38',
#  'Calories39',
#  'Calories40',
#  'Calories41',
#  'Calories42',
#  'Calories43',
#  'Calories44',
#  'Calories45',
#  'Calories46',
#  'Calories47',
#  'Calories48',
#  'Calories49',
#  'Calories50',
#  'Calories51',
#  'Calories52',
#  'Calories53',
#  'Calories54',
#  'Calories55',
#  'Calories56',
#  'Calories57',
#  'Calories58',
#  'Calories59',
#  'Intensity',
#  'Intensity00',
#  'Intensity01',
#  'Intensity02',
#  'Intensity03',
#  'Intensity04',
#  'Intensity05',
#  'Intensity06',
#  'Intensity07',
#  'Intensity08',
#  'Intensity09',
#  'Intensity10',
#  'Intensity11',
#  'Intensity12',
#  'Intensity13',
#  'Intensity14',
#  'Intensity15',
#  'Intensity16',
#  'Intensity17',
#  'Intensity18',
#  'Intensity19',
#  'Intensity20',
#  'Intensity21',
#  'Intensity22',
#  'Intensity23',
#  'Intensity24',
#  'Intensity25',
#  'Intensity26',
#  'Intensity27',
#  'Intensity28',
#  'Intensity29',
#  'Intensity30',
#  'Intensity31',
#  'Intensity32',
#  'Intensity33',
#  'Intensity34',
#  'Intensity35',
#  'Intensity36',
#  'Intensity37',
#  'Intensity38',
#  'Intensity39',
#  'Intensity40',
#  'Intensity41',
#  'Intensity42',
#  'Intensity43',
#  'Intensity44',
#  'Intensity45',
#  'Intensity46',
#  'Intensity47',
#  'Intensity48',
#  'Intensity49',
#  'Intensity50',
#  'Intensity51',
#  'Intensity52',
#  'Intensity53',
#  'Intensity54',
#  'Intensity55',
#  'Intensity56',
#  'Intensity57',
#  'Intensity58',
#  'Intensity59',
#  'METs',
#  'value',
#  'logId',
#  'Steps',
#  'Steps00',
#  'Steps01',
#  'Steps02',
#  'Steps03',
#  'Steps04',
#  'Steps05',
#  'Steps06',
#  'Steps07',
#  'Steps08',
#  'Steps09',
#  'Steps10',
#  'Steps11',
#  'Steps12',
#  'Steps13',
#  'Steps14',
#  'Steps15',
#  'Steps16',
#  'Steps17',
#  'Steps18',
#  'Steps19',
#  'Steps20',
#  'Steps21',
#  'Steps22',
#  'Steps23',
#  'Steps24',
#  'Steps25',
#  'Steps26',
#  'Steps27',
#  'Steps28',
#  'Steps29',
#  'Steps30',
#  'Steps31',
#  'Steps32',
#  'Steps33',
#  'Steps34',
#  'Steps35',
#  'Steps36',
#  'Steps37',
#  'Steps38',
#  'Steps39',
#  'Steps40',
#  'Steps41',
#  'Steps42',
#  'Steps43',
#  'Steps44',
#  'Steps45',
#  'Steps46',
#  'Steps47',
#  'Steps48',
#  'Steps49',
#  'Steps50',
#  'Steps51',
#  'Steps52',
#  'Steps53',
#  'Steps54',
#  'Steps55',
#  'Steps56',
#  'Steps57',
#  'Steps58',
#  'Steps59',
#  'TotalSleepRecords',
#  'TotalMinutesAsleep',
#  'TotalTimeInBed',
#  'WeightKg',
#  'WeightPounds',
#  'BMI']

# %% [markdown]
# <b>4. Analysis Requirements:</b>
#
# What are the requirements of your analysis or modeling tasks?
#
# Are there specific algorithms or analyses that require certain transformations or preprocessing steps?

# %% [markdown]
# <b>1. Data Distribution:</b>
#
# Are the values within a reasonable range for the context of the project?
#
# Are there any outliers that might skew the analysis?
#
# Is the data distribution skewed or heavily tailed?
#
# Does the data exhibit high kurtosis?

# %%
# Assuming data_frames is your list of DataFrames with 'file_name' column added

for df in data_frames:
    # Exclude 'Id' column from numerical columns
    numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
    numerical_columns = numerical_columns.drop('Id')

    # Visualize data distribution
    for col in numerical_columns:
        plt.figure(figsize=(10, 6))
        sns.histplot(data=df, x=col, kde=True)
        plt.title(f'Data Distribution for {col} ({df["file_name"].iloc[0]})')
        plt.xlabel(col)
        plt.ylabel('Frequency')
        plt.show()

    # Calculate summary statistics
    summary_stats = df[numerical_columns].describe()
    #print(f'Summary Statistics for {df["file_name"].iloc[0]}:\n{summary_stats}')

    # Identify outliers
    for col in numerical_columns:
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        if not outliers.empty:
            print(f'Outliers in {col}')

            # Visualize outliers
            plt.figure(figsize=(8, 6))
            sns.boxplot(data=df[col])
            plt.title(f'Boxplot for {col} ({df["file_name"].iloc[0]})')
            plt.xlabel(col)
            plt.show()

    # Assess skewness and kurtosis
    skewness = df[numerical_columns].skew()
    kurtosis = df[numerical_columns].kurtosis()
    print(f'Skewness for {df["file_name"].iloc[0]}:\n{skewness}')
    print(f'Kurtosis for {df["file_name"].iloc[0]}:\n{kurtosis}')

# %% [markdown]
# Skewness:
#
# Skewness measures the asymmetry of the distribution of values in a dataset.
#
# *For a perfectly symmetric distribution, the skewness should be close to 0.
#
# *Positive skewness indicates a longer right tail, so if you're aiming for symmetry, you'd want to reduce positive skewness towards 0.
#
# *Negative skewness indicates a longer left tail, so if you're aiming for symmetry, you'd want to reduce negative skewness towards 0.
#
#
# Kurtosis:
#
# *Kurtosis measures the tailedness or peakedness of the distribution of values in a dataset.
#
# *For a normal distribution, the kurtosis is 3.
#
# *Kurtosis greater than 3 indicates heavier tails and a more peaked distribution (leptokurtic).
#
# *Kurtosis less than 3 indicates lighter tails and a flatter distribution (platykurtic).
#
# *In the output, for example, the skewness value for the StepTotal column is approximately 4.832214, indicating that the distribution is right-skewed.. The kurtosis value for the StepTotal column is approximately 34.200632, indicating a heavily tailed distribution with many values in the tails.
#
# Based on these values, you can infer that the StepTotal column has a right-skewed distribution (positive skewness) and a heavily tailed distribution (high kurtosis). This information provides insights into the shape and characteristics of the distribution of values in the dataset.
#
# Transformations that can be applied to correct skewness and kurtosis:
#
# For Skewness:
#
# *Right-skewed data (positive skewness): square root, logarithm, or reciprocal to reduce the skewness towards 0.
#
# *Left-skewed data (negative skewness), you can apply transformations such as square or cube to reduce the skewness towards 0.
#
# For Kurtosis:
#
# *To reduce excessive kurtosis: square root, logarithm, or reciprocal to flatten the tails and reduce the peakiness of the distribution.
#
# *If the distribution is too flat(low kurtosis): squaring or cubing to increase kurtosis.

# %% [markdown]
# <b>Transformation 1: transform skewed, kutotic and outliered datapoint</b>

# %%
# Loop through each DataFrame in data_frames list
for df in data_frames:
    # Check if column exists in the DataFrame
    for col in df.columns:
        if col == 'skewness' or col == 'kurtosis':
            # Apply transformations to correct skewness and kurtosis
            df[f'{col}Transformed'] = np.sqrt(df[col])  # Square root transformation for skewness
            df.drop(columns=col, inplace=True)
            
            # Check skewness and kurtosis after transformation
            skewness_after = df[f'{col}Transformed'].skew()
            kurtosis_after = df[f'{col}Transformed'].kurtosis()

            print(f'Skewness after transformation: {skewness_after}')
            print(f'Kurtosis after transformation: {kurtosis_after}')
            
            # Apply Box-Cox transformation
            if col == 'outlier':
                df[f'{col}Transformed'], lambda_value = boxcox(df[col] + 1)  # Adding 1 to handle zero values
                df.drop(columns=col, inplace=True)

# %% [markdown]
# <b>5. Normalization or Scaling:</b>
#
# Do the values need to be normalized or scaled to ensure they are on a comparable scale?

# %% [markdown]
# <b>6. Relationships Between Variables:</b>
#
# Are there nonlinear relationships between variables that need to be captured?
#
# Do interaction terms or polynomial features need to be included?

# %% [markdown]
# <b>7. Model Assumptions:</b>
#
# Do the statistical or machine learning models used have specific assumptions about the data distribution or relationships between variables?
#
# Do transformations need to be applied to meet these assumptions?

# %% [markdown]
# <b>8. Interpretability:<b>
#
# How will the transformations affect the interpretability of the data?
#
# Will the transformations alter the original scale or meaning of the variables?

# %% [markdown]
# <b>9. Handling Zeros or Negative Values:</b>
#
# How will zeros or negative values be handled in the data?
#
# Are there transformations that are not applicable due to the presence of zeros or negative values?

# %% [markdown]
# <b>12. Data encoding:</b>
#
# Do boolean values need to be encoded to 1 for True and 0 for False?
#
# How will data encoding of boolean/or categorical values impact data interpretation and analysis?
#
# Do you need to add comments to indicate the meaning of True (1) and False (0) in the respective columns?
#
# I encoded the boolean values in the 'boolean_column' as integers, where True is represented as 1 and False as 0."

# %%
import pandas as pd

# Assuming df is your DataFrame and 'boolean_column' is the boolean column
df['boolean_column'] = df['boolean_column'].astype(int)

# Alternatively, you can use a mapping function
# df['boolean_column'] = df['boolean_column'].map({True: 1, False: 0})

# %% [markdown]
# <b>Datetime Decomposition:</b>
#
# This term describes the process of breaking down a datetime variable into its constituent parts, such as date and time components.
#
# Do datetime values need to be split into separate date and time columns?
#
# How will splitting datetime values impact subsequent analysis or modeling tasks?

# %% [markdown]
# <b>Row Identification:</b>
#
# This term describes the process of assigning a unique identifier to each row in a dataset.
#
# Is it necessary to add a unique identifier to each row in the dataset?
#
# How will the addition of a unique ID affect data manipulation and analysis?
#
# "I performed row identification by adding a unique ID to each row in the DataFrame."

# %%
    # Initialize serial number
    serial_number = 1
    
    def generate_unique_id(file_name):
        """
        Generate a unique ID based on the file name and auto-incrementing serial number.
        
        Args:
        - file_name (str): Name of the file.
        
        Returns:
        - str: Unique ID.
        """
        nonlocal serial_number  # Use the serial_number variable from the outer function
        initials = ''.join(word[0].upper() for word in file_name.split('_'))
        unique_id = f'{initials}{serial_number}'
        serial_number += 1  # Increment serial number
        return unique_id

# %%
min(data_frames[6]['AverageIntensity'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming outliers DataFrame contains the outlier observations
# Assuming the column with outliers is 'Column_with_outliers'
# Replace 'Column_with_outliers' with the actual column name

# Plot a boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(data=data_frames[6]['AverageIntensity'])
plt.title('Boxplot of Column with Outliers')
plt.xlabel('Column Name')
plt.show()

# %%
# Plot a boxplot
plt.figure(figsize=(8, 6))
sns.histplot(data=data_frames[6]['AverageIntensity'])
plt.title('Histplot of Column with Outliers')
plt.xlabel('Column Name')
plt.show()

# %%
from scipy.stats import boxcox

# Apply Box-Cox transformation
transformed_data, lambda_value = boxcox(df['AverageIntensity'] + 1)  # Adding 1 to handle zero values
df['AverageIntensityTransformed'] = transformed_data

# %%
data_frames[6]

# %%
# Plot a boxplot
plt.figure(figsize=(8, 6))
sns.histplot(data=data_frames[6]['AverageIntensityTransformed'])
plt.title('Histplot of Column with Outliers')
plt.xlabel('Column Name')
plt.show()

# %%
# Plot a boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(data=data_frames[6]['AverageIntensityTransformed'])
plt.title('Histplot of Column with Outliers')
plt.xlabel('Column Name')
plt.show()

# %%
data_frames[17].info()

# %%
data_frames[17]['Fat'].isnull().sum()/len(data_frames[17]['Fat'])*100

# %%
if df[col].iloc[1] like "4/12/2016 12:00:00 AM" => split to date, time and am/pm column and convert to appropriate datatype

if df[col].iloc[1] like "4/12/2016" => convert to appropriate datatype (date)

# %%
SOURCE_USERNAME = 'fitbase'
SOURCE_PASSWORD = 'fitbase'
SOURCE_SERVER = 'localhost'
SOURCE_DATABASE = 'projectfitbase'

DEST_USERNAME = 'fitbase'
DEST_PASSWORD = 'fitbase'
DEST_SERVER = 'localhost'
DEST_DATABASE = 'projectfitbasetransformed'

# %%
# Source database connection string
source_conn_str = f'postgresql://{SOURCE_USERNAME}:{SOURCE_PASSWORD}@{SOURCE_SERVER}/{SOURCE_DATABASE}'

# Destination database connection string
dest_conn_str = f'postgresql://{DEST_USERNAME}:{DEST_PASSWORD}@{DEST_SERVER}/{DEST_DATABASE}'

# Establish connections to source and destination databases
source_engine = create_engine(source_conn_str)
dest_engine = create_engine(dest_conn_str)

# Reflect metadata from source database
metadata = MetaData()
metadata.reflect(bind=source_engine)

# List to store extracted dataframes
extracted_datax = []

# Loop through each table in the source database
for table_name, table in metadata.tables.items():
    # Extract data from the current table
    with source_engine.connect() as source_conn:
        extract_query = table.select()
        extracted_data = source_conn.execute(extract_query).fetchall()
        
        # Convert extracted data to DataFrame
        df = pd.DataFrame(extracted_data, columns=table.columns.keys())
        
        # Append DataFrame to the list
        extracted_datax.append(df)

    # Transform data as needed
    #transformed_data = transform_data(extracted_data)

    # Load transformed data into the destination database
    #with dest_engine.connect() as dest_conn:
        #dest_conn.execute(table.insert(), transformed_data)

print("ETL process completed successfully.")
